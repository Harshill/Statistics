# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as graph

from statsmodels.formula.api import ols
from sklearn.datasets import make_regression
from IPython.display import display

graph.style.use('fivethirtyeight')

# %%
x, y = make_regression(n_samples=100, n_features=3, n_informative=2)

display(x.shape)
display(y.shape)
# Out:
# (100, 3)
# (100,)

# %%
data = pd.DataFrame(x)
data.columns = ['x1', 'x2', 'x3']
data['y'] = y

display(data.head())
# Out:
#          x1        x2        x3           y
# 0  0.820944  0.339819  1.116010   74.164855
# 1  2.202275  1.214955 -0.053045  225.391856
# 2 -0.144431 -0.565289  1.020883  -57.101221
# 3  2.237384  0.909351 -1.078931  200.664630
# 4  0.385906  0.856527  0.420616   95.585940

# %%
for column in data.columns:
    graph.hist(data[column])
    graph.xlabel(column)
    graph.show()

# %%
sns.pairplot(data)
graph.show()

# %%
ols_model = ols('y ~ x1 + x2 + x3', data=data)
results = ols_model.fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.583e+32
# Date:                Wed, 03 Oct 2018   Prob (F-statistic):               0.00
# Time:                        10:18:07   Log-Likelihood:                 2998.0
# No. Observations:                 100   AIC:                            -5988.
# Df Residuals:                      96   BIC:                            -5978.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.776e-15   2.39e-15      0.744      0.459   -2.96e-15    6.52e-15
# x1            54.2676   2.46e-15   2.21e+16      0.000      54.268      54.268
# x2            87.1471   2.52e-15   3.46e+16      0.000      87.147      87.147
# x3         -6.661e-15   2.35e-15     -2.835      0.006   -1.13e-14      -2e-15
# ==============================================================================
# Omnibus:                        1.454   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.483   Jarque-Bera (JB):                0.920
# Skew:                          -0.163   Prob(JB):                        0.631
# Kurtosis:                       3.338   Cond. No.                         1.39
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
